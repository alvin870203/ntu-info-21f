# %% [markdown]
# # Psychoinformatics - Week 4 (Examples)
# by Tsung-Ren (Tren) Huang (trhuang@g.ntu.edu.tw)

# %% [markdown]
# ## 0 Package Installation

# %%
# # !pip install dcard-spider facebook-sdk  # no use, don't install
# !pip install tweepy
# !pip install oauth2 google-api-python-client
# !pip install --upgrade oauth2client

# %% [markdown]
# ## 1 Dcard
# Check out <a href=https://blog.jiatool.com/posts/dcard_api_v2/>this webpage</a> for more details about the Dcard APIs.

# %%
import urllib.request,json
u='https://www.dcard.tw/_api/posts/226048661'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
j_data=json.loads(data.decode('utf-8'))
print(j_data['media'][0]['url'])
for key in j_data.keys():
  print(key,':',j_data[key])
# Out:
# https://i.imgur.com/lof9lya.jpg
# id : 226048661
# title : 套房隔音太差，常常聽到鄰居的...
# content : 我租的套房雖然是水泥隔間
# 但因為屋頂是輕鋼架所以隔音還是不太好
# 沒聽過隔壁貓叫春
# 只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌
#
# 某天被她吵得不行
# 一怒之下把wifi熱點的名字改成
#
# https://i.imgur.com/lof9lya.jpg
#
#
#
# 但我晚上其實不一定在家
# 所以後來也忘了這件事
# 名字也沒改回來
#
# 昨天晚上打電動打到一半wifi突然跳出來
# 看到這個名字我當場笑噴
#
# https://i.imgur.com/GQULLhd.jpg
#
# 看來不只我一個人崩潰啊哈哈哈
# 這位鄰居我好想認識你喔～
# excerpt : 我租的套房雖然是水泥隔間，但因為屋頂是輕鋼架所以隔音還是不太好，沒聽過隔壁貓叫春，只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌，某天被她吵得不行，一怒之下把wifi熱點的名字改成，但我晚上其實不一定在家
# anonymousSchool : False
# anonymousDepartment : False
# pinned : False
# forumId : a1aaa6e6-2594-4968-b7dc-e1b14bea96f4
# replyId : None
# createdAt : 2017-03-25T04:32:58.141Z
# updatedAt : 2018-07-26T00:19:20.397Z
# commentCount : 384
# likeCount : 44054
# tags : ['水泥', '一怒之下', '叫春', '跳出來', '熱點', '打電動', '聽過', '隔音', '鋼架', '隔壁', '名字', '套房', '不一定', '改回來', '屋頂', '吵得', 'wifi', '隔間', '...', '是輕', '件事']
# topics : []
# supportedReactions : None
# withNickname : False
# reportReason :
# ...

# %%
# # Not working anymore

# from dcard import Dcard
# def filter(metas):
#  return [m for m in metas if m['likeCount'] >= 50]
#  #return [m for m in metas if "女友" in m['topics']]

# d=Dcard()
# f=d.forums('photography') #攝影版
# m=f.get_metas(num=500,callback=filter) #list
# p=d.posts(m).get(comments=False)
# r=p.parse_resources() #list: try r[0][1]
# done,fails=p.download(r)
# print('Got %d pics' % done if len(fails)==0 else 'Error!')

# %%
u='https://www.dcard.tw/service/api/v2/forums/photography/posts?limit=100'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
j_data=json.loads(data.decode('utf-8'))
c=0
for post in j_data:
    if('貓' in post['topics']):
        print(post['id'])
        for i in range(len(post['media'])):
            url=post['media'][i]['url']
            urllib.request.urlretrieve(url,'./downloads/'+str(post['id'])+'_'+url.rsplit('/', 1)[-1])
# Out:
# 237239296
# 237236942
# 237235658
# 237227980
# 237208446
# 237202059

# %% [markdown]
# ## Facebook

# %%
# # Too much restriction on permission

# import json
# def show(j_in):
#   print(json.dumps(j_in,ensure_ascii=False,indent=2))

# import facebook

# # Need to generate new token, hard to use.
# token='EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD'  # replaced by your access token

# graph=facebook.GraphAPI(token)
# show(graph.get_object('me',fields='id,name,email,age_range,posts'))
# show(graph.get_connections('me','friends'))
# #graph.put_object('me','feed',message='Hello from class!')
# # see https://stackoverflow.com/questions/52353828/posting-to-facebook-with-python-and-graph-api-permissions-issue

# %%
# # Too much restriction on permission

# import json
# def show(j_in):
#   print(json.dumps(j_in,ensure_ascii=False,indent=2))

# import facebook

# # Need to generate new token, hard to use.
# token='EAAYAOVZA9YWQBADX7gnvTQoQ5e5SxMmTqwVtMP4EcM4AvK4hcd5zduK20gtfqJEzVWlvkMIJQ8wwBC8ZB10wMbmV68vbpbRoR4dRiFVsEpVGKpwzutXT1RoYSOAyTmgJ6pb7d86ZBwWeevTk6WmHzLKlvR2v8wV6S0Pj2oeuLmOZBYkqNYLVwoTJoF1XRhuQ2GLCIsIBZBQZDZD'  # replaced by your access token

# graph=facebook.GraphAPI(token)
# show(graph.get_connections('me','friends'))
# show(graph.get_object('me',fields='id,name,email,age_range,posts'))
# #graph.put_object('me','feed',message='Hello from class!')
# # see https://stackoverflow.com/questions/52353828/posting-to-facebook-with-python-and-graph-api-permissions-issue

# %% [markdown]
# ## Twitter

# %%
import tweepy
key1='HDTBqZDAOuZJyDhsr5Z5tw' # API key 
secret1='nKULl80bwwedY4jtk4UTt2dXotoIVOlPQ8fUVK2LDo' # API secret
key2='206228745-rPUeOG5ZP6Wi3nV5Zd4bwYLRkxthdHVMuidsAbRn' # Access token  
secret2='XcPdcCDXu54FpaYD58KrBQTkCJwsQOdiFpQCbOLh2D09N' # Token secret
auth=tweepy.OAuthHandler(key1,secret1)
auth.set_access_token(key2,secret2)
api=tweepy.API(auth)
data=api.search_tweets(q=u'高雄',geocode='22.78,120.555,500km')
for tweet in data:
  print(tweet.user.screen_name,tweet.text,'\n')
# Out:
# TaiwanTodayJP 蔡総統がビル火災の高雄市を訪問、けが人を見舞い葬儀場では犠牲者悼む
# （2021.10.18）
# #死者46人負傷者41人
# #都市再開発で再発防止
# https://t.co/i4uJ004qGG
#
# setlivenews 在路中央"測跳遠"? 高雄汽機車道驚見"神秘標線".白色方格一路延伸"用途"引發討論! 交通局出面解釋:提醒用路人減速...│https://t.co/LTGYVBQ6mD https://t.co/YW5qgWLeDv
#
# klc_ruoshui https://t.co/9T3IKv7Ts8
#
# Quote：
# 國民黨繼6日公布高雄市黨部主委人事案後，今天發布桃園市等15個縣市黨部主任委員人事案，連同日前發布的高雄市黨部主委，共已發布16個縣市黨部主委人事。目前還有台北市、新… https://t.co/Ld1DWdeRPV
#
# eason1305 沒記錯的話，這個有騷擾嫌疑的人之前有推特，我也在賦茶看過他，也是寫過高雄地方政治角力分析的 Neverdry https://t.co/gGMqVR39GL
#
# Iamlilian0318 @flyChengEcho 來高雄要吃看看喔👍
#
# Cottoncandysis Blue Monday
#
# 大家一起加油吧😎😎😎
#
# #高雄 https://t.co/63vP41vdlh
#
# lyh610226 #高雄 真美 https://t.co/qxTfRby1hi
#
# jillannda 無謊不說，再怎麼不合邏輯，極度怪力亂神的謊言都編造得出來‼可怕變態至極‼
# 🔺我們家不是他們家，我們也不認識他們，隔壁這户(高雄市灣愛街35號)究竟是哪裡來的變態惡徒？!
# https://t.co/jeuPigAswq https://t.co/7NLmqqjx9x
#
# jillannda 自從我母親於2010.5.4過世後，我們便將所有權登記在我大哥"孫銘源"名下。我們家從不曾將房子出租給任何人，而自從我母親過世至今，這屋子則一直只住著我們兩個女同性戀，別無他人‼沒有男的，更不可能有小孩‼
# 🔴這個長年竊聽跟蹤造謠迫… https://t.co/mK6oD0e6N1
#
# ...

# %%
for follower in api.get_follower_ids(screen_name='iingwen'):
  user=api.get_user(user_id=follower)
  print(user.screen_name,'\t',user.name)
# Out:
# ELBCzT4DurhxYSV 	 最后的勇士
# TcZQJzK8RB5WAgz 	 后果拿铁
# sayaka_111222 	 🌻KEN🌻
# shixin0913 	 stone .
# surviveroflove 	 南波万🇨🇳
# 9GyXSbIIBUFildh 	 于沛
# CedUQEDOF4tyBWd 	 王高昭
# HollyLo85623074 	 Holly Lopez
# LinSiCheng5 	 阿林
# 118Travis 	 travis.118
# jiangdou13 	 江逗
# daylight_frank 	 Frank Chen
# biyel944 	 Peiyu
# Ideal_1413 	 Ideal
# SimonSha18 	 Simon Sha
# A1uKc 	 佐藤
# MarkT_Image 	 Mark Tang
# LeoLYeah 	 Ye Liu
# lushuai50123658 	 lu shuai
# SusanBe57804267 	 Susan Bell
# WendyCh50435130 	 Wendy Chen
# wuyooy 	 wuyooy
# Alanchan449 	 Alan Chan
# GaesornT 	 Gaesorn
# Cabdika34086148 	 Cabdikaafi
# KGfcynYGHmiK8cL 	 中川禄程
# AshleyH52464209 	 Ashley Hughes
# Ladan82658755 	 Nice_An
# JasonHh9 	 Jason Hh
# h54973392 	 hhh
# Kb1ARLhSI2SVvtZ 	 万猛
# jWS7pchpydruIl2 	 ボット2
# nZuEjZazf5fytK7 	 河野
# SaburouKurumi 	 Saburou Kurumi
# aabb603030731 	 aabb
# SteffensDolores 	 Dolores Steffens
# walkershing1 	 walkershing
# wjfAjNtZMF0Ky3L 	 张夜空
# tN51bZw8dnJB3Kh 	 王俊良
# P9HB7zQx21uUzF5 	 del
# ...

# %% [markdown]
# ## Google

# %%
DEVELOPER_KEY = "AIzaSyCc2rHRg-LdpJ_sTinJigHR2o-FArFhVpw"

# %% [markdown]
# The following list contains the <b>part</b> names that you can include in the parameter value:
# - contentDetails
# - fileDetails
# - id
# - liveStreamingDetails
# - localizations
# - player
# - processingDetails
# - recordingDetails
# - snippet
# - statistics
# - status
# - suggestions
# - topicDetails
#
# The <b>regionCode</b> parameter value is an ISO 3166-1 alpha-2 country code.
#
# Maximum value for <b>maxResults</b> i 50.

# %%
# import package "googleapiclient.discovery" instead of "apiclient.discovery"
# to solve the error message 'Import "apiclient.discovery" could not be resolvedPylance'
# in vscode integrated jupyter notebook.
from googleapiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=DEVELOPER_KEY)
result = youtube.videos().list(
    part='snippet,contentDetails,statistics',
    chart='mostPopular',
    regionCode='TW',maxResults=50).execute()
print(result)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'kPr6eRNUs6aiUBF1iRLJPW1j63Q', 'items': [{'kind': 'youtube#video', 'etag': '61C4Miq3a0BzlxTXEEhVSz1Rrp0', 'id': '-Rp7UPbhErE', 'snippet': {'publishedAt': '2021-10-15T10:00:12Z', 'channelId': 'UCFUtqTcgJgRnmZ3tMU6P74Q', 'title': '聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician', 'description': "這是一首充滿了粉紅色的浪漫甜蜜情歌，請玻璃心患者慎入... 也請大家關注黃明志最新剛剛開的微博賬號 https://weibo.com/u/7684024922\n\n@Kimberley Chen  is in the house! Opps! We didn't mean to break your heart...💔\n\n⚠️Please be cautious if you are Fragile Pink⚠️\n\n黃明志2021最新實體專輯【鬼才做音樂】11月正式發行，今天開始預購！Namewee's latest music album of 2021 [Ghosician] will be officially released in November, and Pre-order starts today! https://bit.ly/3BM4IIe\n\n\n《玻璃心 Fragile》Youtube 高清版MV：https://bit.ly/30GjD9j\n\nThe Making Of《玻璃心 Fragile》幕後花絮 Youtube高清版 : https://youtu.be/TTd7M9QjM3M\n\n《玻璃心 Fragile》數位音樂下載 Online Music Download：https://lnk.to/fragilepink\n\n《玻璃心 Fragile》Shorts 高清版：https://youtu.be/PdoGtBQFtbg\n\n《
# ...

# %%
# print above dict result as indented json
import json
json_str = json.dumps(result, ensure_ascii=False, indent=4)
print(json_str)
# Out:
# {
#     "kind": "youtube#videoListResponse",
#     "etag": "kPr6eRNUs6aiUBF1iRLJPW1j63Q",
#     "items": [
#         {
#             "kind": "youtube#video",
#             "etag": "61C4Miq3a0BzlxTXEEhVSz1Rrp0",
#             "id": "-Rp7UPbhErE",
#             "snippet": {
#                 "publishedAt": "2021-10-15T10:00:12Z",
#                 "channelId": "UCFUtqTcgJgRnmZ3tMU6P74Q",
#                 "title": "聽見玻璃心碎的聲音... 黃明志 Ft.陳芳語【玻璃心】@鬼才做音樂 2021 Ghosician",
# ...

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

    youtube = build('youtube','v3',developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    favoriteCount = []
    category = []
    tags = []
    videos = []
    
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":

            title.append(search_result['snippet']['title']) 

            videoId.append(search_result['id']['videoId'])

            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()

            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
        if 'commentCount' in response['items'][0]['statistics'].keys():
            commentCount.append(response['items'][0]['statistics']['commentCount'])
        else:
            commentCount.append([])
        if 'tags' in response['items'][0]['snippet'].keys():
            tags.append(response['items'][0]['snippet']['tags'])
        else:
            tags.append([])

    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

    return youtube_dict

# %%
import pandas as pd
test = youtube_search("高雄")
df = pd.DataFrame(data=test)
df
# Out:
#                                                  tags  \
# 0   [TBS, NEWS, ニュース, TBSNEWS, 報道, 日本, Japan, 最新ニュース]
# 1                             [ニュース, テレビ朝日, provided]
# 2   [ニュース, NEWS, FNN, FNNプライムオンライン, フジテレビ, フジテレビジョ...
# 3   [TBS, NEWS, ニュース, TBSNEWS, 報道, 日本, Japan, 最新ニュース]
# 4   [食尚玩家, 不推怎麼行, 食尙玩家歡樂有夠讚, 詹姆士, 莎莎, 時尚玩家, 美食, 小吃...
# 5                      [交通消息, 天氣報道, 手語傳譯, 時事資訊, 潮傾天下]
# 6   [高雄, 高雄景點, 高雄旅遊, 高雄行程, 2021新景點, 大港橋, HOLOPARK,...
# 7                      [台灣美食, 台灣, 高雄美食, 高雄, 傳統小吃, 火鍋]
# 8                                                  []
# 9   [新聞雲, ettoday, 東森, 新聞, 社會新聞, 火災, 城中城, 高雄, 城中城 ...
# 10  [我是馬鈴薯小姐雁靈, 高雄旅遊, 台灣旅遊, 兩天一夜遊, 吃貨行程, 高雄必吃美食, 丹...
# 11  [壹加壹, 一加一, ILLY and LEAN, ILLY, LEAN, 高雄, 景點, ...
# 12                           [高雄, 鹽埕區, 駁二, 鴨肉珍, 樺達奶茶]
# 13  [新聞雲, ettoday, 東森, 新聞, 社會新聞, 火災, 城中城, 高雄, 城中城 ...
# 14  [ETTV, Ch51, 東森, EBC, 白心儀, 1001, 1001個故事, 東森新聞...
# 15  [少康戰情室, 少康, 習近平, 习近平, XiJinping, 大陸, 中國, 中国, 少...
# ...
